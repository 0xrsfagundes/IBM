# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_stata('csv/eitc.dta')

df.head()
# Out:
#    state    year  urate  children  nonwhite          finc          earn  age  \
# 0   11.0  1991.0    7.6         0         1  18714.394273  18714.394273   26
# 1   12.0  1991.0    7.2         1         0   4838.568282    471.365639   22
# 2   13.0  1991.0    6.4         2         0   8178.193833      0.000000   33
# 3   14.0  1991.0    9.1         0         1   9369.570485      0.000000   43
# 4   15.0  1991.0    8.6         3         1  14706.607930  14706.607930   23
#
#    ed  work    unearn
# 0  10     1  0.000000
# 1   9     1  4.367203
# 2  11     0  8.178194
# 3  11     0  9.369570
# 4   7     1  0.000000

# %%
df['post93'] = np.where(df['year'] > 1993, 1, 0)
df['mom'] = np.where(df['children'] > 0, 1, 0)
df['mom_post93'] = df['post93'] * df['mom']

df.head()
# Out:
#    state    year  urate  children  nonwhite          finc          earn  age  \
# 0   11.0  1991.0    7.6         0         1  18714.394273  18714.394273   26
# 1   12.0  1991.0    7.2         1         0   4838.568282    471.365639   22
# 2   13.0  1991.0    6.4         2         0   8178.193833      0.000000   33
# 3   14.0  1991.0    9.1         0         1   9369.570485      0.000000   43
# 4   15.0  1991.0    8.6         3         1  14706.607930  14706.607930   23
#
#    ed  work    unearn  post93  mom  mom_post93
# 0  10     1  0.000000       0    0           0
# 1   9     1  4.367203       0    1           0
# 2  11     0  8.178194       0    1           0
# 3  11     0  9.369570       0    0           0
# 4   7     1  0.000000       0    1           0
