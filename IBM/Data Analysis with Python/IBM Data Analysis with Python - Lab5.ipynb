# %% [markdown]
# # Data Analysis with Python - Lab5
#
# IBM course - Data Analysis with Python

# %%
import pandas as pd

df = pd.read_csv('csv/automobileEDA.csv')

df.sort_index(axis=1, inplace = True)

df.head()
# Out:
#   aspiration   body-style  bore  city-L/100km  city-mpg  compression-ratio  \
# 0        std  convertible  3.47     11.190476        21                9.0
# 1        std  convertible  3.47     11.190476        21                9.0
# 2        std    hatchback  2.68     12.368421        19                9.0
# 3        std        sedan  3.19      9.791667        24               10.0
# 4        std        sedan  3.19     13.055556        18                8.0
#
#    curb-weight  diesel drive-wheels engine-location  ...         make  \
# 0         2548       0          rwd           front  ...  alfa-romero
# 1         2548       0          rwd           front  ...  alfa-romero
# 2         2823       0          rwd           front  ...  alfa-romero
# 3         2337       0          fwd           front  ...         audi
# 4         2824       0          4wd           front  ...         audi
#
#   normalized-losses num-of-cylinders  num-of-doors  peak-rpm    price  stroke  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   aspiration         201 non-null    object
#  1   body-style         201 non-null    object
#  2   bore               201 non-null    float64
#  3   city-L/100km       201 non-null    float64
#  4   city-mpg           201 non-null    int64
#  5   compression-ratio  201 non-null    float64
#  6   curb-weight        201 non-null    int64
#  7   diesel             201 non-null    int64
#  8   drive-wheels       201 non-null    object
#  9   engine-location    201 non-null    object
#  10  engine-size        201 non-null    int64
#  11  engine-type        201 non-null    object
#  12  fuel-system        201 non-null    object
#  13  gas                201 non-null    int64
#  14  height             201 non-null    float64
#  15  highway-mpg        201 non-null    int64
# ...

# %%
df_corr = df.corr(numeric_only=True)

df_corr
# Out:
#                        bore  city-L/100km  city-mpg  compression-ratio  \
# bore               1.000000      0.554610 -0.582027           0.001263
# city-L/100km       0.554610      1.000000 -0.949713          -0.299372
# city-mpg          -0.582027     -0.949713  1.000000           0.331425
# compression-ratio  0.001263     -0.299372  0.331425           1.000000
# curb-weight        0.644060      0.785353 -0.749543           0.156433
# diesel             0.054458     -0.241282  0.265676           0.985231
# engine-size        0.572609      0.745059 -0.650546           0.028889
# gas               -0.054458      0.241282 -0.265676          -0.985231
# height             0.180449      0.003811 -0.049800           0.259737
# highway-mpg       -0.591309     -0.930028  0.972044           0.268465
# horsepower         0.566936      0.889488 -0.822214          -0.214514
# length             0.608971      0.657373 -0.665192           0.159733
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(df_corr, annot=True, annot_kws={"fontsize":5})
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(df_corr.loc[['bore','stroke','compression-ratio','horsepower']][['bore','stroke','compression-ratio','horsepower']], annot=True, annot_kws={"fontsize":6})
plt.show()

# %%
# Engine size as potential predictor variable of price
sns.regplot(x="engine-size", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 53137.65711953844)

# %%
df[['engine-size','price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
sns.regplot(x='highway-mpg',y='price',data=df)
plt.ylim(0,)
# Out:
# (0.0, 48180.26233771478)

# %%
df[['highway-mpg','price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000
